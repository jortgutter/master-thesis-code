# %%
from asynctorch_experiments.evaluation.monitor import Monitor, SpikeMonitor, TestClass, TestMonitor 


test_obj = TestClass(value=2)
TestMonitor(test_obj)
SpikeMonitor(test_obj)
for i in range(100):
    test_obj.increment()
    test_obj.add_potentials()


    test_obj._log_monitors()
test_obj._plot_monitors()
print(test_obj._get_monitors())
# Out:
# test
# attempting to register a test monitor
# test
# attempting to register a spike monitor
# tensor([[3., 0., 2., 1., 3., 3., 3., 3., 2., 1., 2.],
#         [0., 0., 1., 0., 3., 2., 1., 0., 0., 3., 2.],
#         [3., 0., 1., 1., 2., 2., 0., 3., 1., 0., 0.],
#         [2., 2., 1., 0., 0., 0., 2., 1., 2., 1., 2.]], dtype=torch.float64)
# logging spikes (0)
# tensor([[3., 0., 4., 2., 5., 6., 5., 3., 2., 3., 4.],
#         [2., 3., 1., 2., 3., 3., 2., 2., 3., 5., 3.],
#         [3., 1., 4., 4., 4., 3., 2., 3., 4., 0., 1.],
#         [3., 4., 2., 0., 3., 1., 4., 3., 4., 4., 4.]], dtype=torch.float64)
# logging spikes (1)
# tensor([[4., 0., 4., 5., 5., 9., 8., 6., 5., 5., 4.],
#         [3., 5., 3., 2., 3., 4., 5., 2., 3., 6., 5.],
#         [5., 2., 7., 5., 4., 5., 2., 4., 7., 0., 4.],
#         [5., 6., 4., 2., 4., 1., 5., 5., 4., 4., 5.]], dtype=torch.float64)
# logging spikes (2)
# tensor([[ 7.,  2.,  7.,  5.,  7., 10.,  9.,  6.,  5.,  5.,  7.],
# ...
